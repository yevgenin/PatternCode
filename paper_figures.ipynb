# %%
# %reload_ext autoreload
# %autoreload 2
import os
os.environ["PC_QUICK_RUN"] = "0"
from patterncode.figures import *
from patterncode.genome_data import *
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
NCBIGenome.download_genomes()
# Out:
# ...
# Skipping:  human
# Skipping:  /Users/user1/data/download/human
# Skipping:  Salmonella enterica
# Skipping:  /Users/user1/data/download/bacteria/Salmonella enterica
# Skipping:  Escherichia coli K12
# Skipping:  /Users/user1/data/download/bacteria/Escherichia coli K12
# Skipping:  Staphylococcus aureus
# Skipping:  /Users/user1/data/download/bacteria/Staphylococcus aureus
# Skipping:  Streptococcus pyogenes
# Skipping:  /Users/user1/data/download/bacteria/Streptococcus pyogenes
# Skipping:  Klebsiella pneumoniae
# Skipping:  /Users/user1/data/download/bacteria/Klebsiella pneumoniae
# Skipping:  Mycobacterium tuberculosis
# Skipping:  /Users/user1/data/download/bacteria/Mycobacterium tuberculosis
# Skipping:  Pseudomonas aeruginosa
# Skipping:  /Users/user1/data/download/bacteria/Pseudomonas aeruginosa
# Skipping:  Proteus mirabilis
# Skipping:  /Users/user1/data/download/bacteria/Proteus mirabilis
# Skipping:  Citrobacter koseri
# ...

# %%
dna_fragment_illustration_figure()
# Out:
# Setting random seed to:  1799144579

# %%
p_err_vs_fragment_len_figure()
# Out:
# Setting random seed to:  1799144579
# Loading latest
# Loading: /Users/user1/Dropbox/out/len-human_genome_20230508T192136Z-idealistic-bear.pkl
# Setting random seed to:  1799144579
# Loading latest
# Loading: /Users/user1/Dropbox/out/len-bacterial_genomes_20230508T192136Z-idealistic-bear.pkl
# Setting random seed to:  1799144579
# Loading latest
# Loading: /Users/user1/Dropbox/out/len-random_genome_20230508T192136Z-idealistic-bear.pkl

# %%
PErrVsPattern.make(genome_name=HUMAN_GENOME, load=1, plot=1, patterns=REBASE_NICKING_PATTERNS).data_table().to_csv('human.csv')
# Out:
# Setting random seed to:  1799144579
# Loading latest
# Loading: /Users/user1/Dropbox/out/pattern-human_genome_20230516T124811Z-white-mantis.pkl

# %%
ls
# Out:
# README.md             environment.yml       patterncode/
# bacteria.csv          example.ipynb         patterncode.egg-info/
# data/                 human.csv             setup.py
# env_base.yml          paper_figures.ipynb

# %%
PErrVsPattern.make(genome_name=BACTERIAL_GENOMES, load=1, plot=1, patterns=REBASE_NICKING_PATTERNS).data_table().to_csv('bacteria.csv')
# Out:
# Setting random seed to:  1799144579
# Loading latest
# Loading: /Users/user1/Dropbox/out/pattern-bacterial_genomes_20230516T124811Z-white-mantis.pkl

# %%
p_err_vs_pattern_figure()
# Out:
# Setting random seed to:  1799144579
# Loading latest
# Loading: /Users/user1/Dropbox/out/pattern-human_genome_20230516T123444Z-fabulous-bulldog.pkl
# Setting random seed to:  1799144579
# Loading latest
# Loading: /Users/user1/Dropbox/out/pattern-bacterial_genomes_20230516T123444Z-fabulous-bulldog.pkl
# Setting random seed to:  1799144579
# Loading latest
# Loading: /Users/user1/Dropbox/out/pattern-random_genome_20230515T233547Z-ginger-pegasus.pkl

# %%
bacterial_genomes_table()
# Out:
# Loading genome: bacterial_genomes
#                                             Organism        Accession  \
# 0                    Citrobacter koseri ATCC BAA-895  GCF_000018045.1
# 1          Escherichia coli str. K-12 substr. MG1655  GCF_000005845.2
# 2    Klebsiella pneumoniae subsp. pneumoniae HS11286  GCF_000240185.1
# 3                   Mycobacterium tuberculosis H37Rv  GCF_000195955.2
# 4                           Proteus mirabilis HI4320  GCF_000069965.1
# 5                        Pseudomonas aeruginosa PAO1  GCF_000006765.1
# 6  Salmonella enterica subsp. enterica serovar Ty...  GCF_000006945.2
# 7      Staphylococcus aureus subsp. aureus NCTC 8325  GCF_000013425.1
#
#    Sequence ID  Sequence Length
# 0  NC_009792.1          4720462
# 1  NC_000913.3          4641652
# 2  NC_016845.1          5333942
# 3  NC_000962.3          4411532
# 4  NC_010554.1          4063606
# 5  NC_002516.2          6264404
# 6  NC_003197.2          4857450
# 7  NC_007795.1          2821361
# ...
